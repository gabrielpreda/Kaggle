# %%
import pandas as pd
import numpy as np
import os
import sys

# %%
vaccination_path = "../../covid-19-data/public/data/vaccinations"

os.listdir(vaccination_path)
# Out:
# ['country_data', 'locations.csv', 'README.md', 'vaccinations.csv']

# %%
country_files = os.listdir(os.path.join(vaccination_path, 'country_data'))
country_df = pd.DataFrame()
for country in country_files:
    data_df = pd.read_csv(os.path.join(vaccination_path, 'country_data', country))
    country_df = country_df.append(data_df)

# %%
country_df.shape
# Out:
# (481, 7)

# %%
country_df.loc[country_df.location=="Bahrain"]
# Out:
#    location        date                     vaccine  \
# 0   Bahrain  2020-12-23  Pfizer/BioNTech, Sinopharm
# 1   Bahrain  2020-12-24  Pfizer/BioNTech, Sinopharm
# 2   Bahrain  2020-12-25  Pfizer/BioNTech, Sinopharm
# 3   Bahrain  2020-12-26  Pfizer/BioNTech, Sinopharm
# 4   Bahrain  2020-12-27  Pfizer/BioNTech, Sinopharm
# 5   Bahrain  2020-12-28  Pfizer/BioNTech, Sinopharm
# 6   Bahrain  2020-12-29  Pfizer/BioNTech, Sinopharm
# 7   Bahrain  2020-12-30  Pfizer/BioNTech, Sinopharm
# 8   Bahrain  2020-12-31  Pfizer/BioNTech, Sinopharm
# 9   Bahrain  2021-01-01  Pfizer/BioNTech, Sinopharm
# 10  Bahrain  2021-01-02  Pfizer/BioNTech, Sinopharm
# 11  Bahrain  2021-01-03  Pfizer/BioNTech, Sinopharm
# 12  Bahrain  2021-01-04  Pfizer/BioNTech, Sinopharm
# 13  Bahrain  2021-01-05  Pfizer/BioNTech, Sinopharm
# 14  Bahrain  2021-01-06  Pfizer/BioNTech, Sinopharm
# 15  Bahrain  2021-01-07  Pfizer/BioNTech, Sinopharm
# 16  Bahrain  2021-01-08  Pfizer/BioNTech, Sinopharm
# 17  Bahrain  2021-01-09  Pfizer/BioNTech, Sinopharm
# 18  Bahrain  2021-01-10  Pfizer/BioNTech, Sinopharm
# 19  Bahrain  2021-01-11  Pfizer/BioNTech, Sinopharm
# 20  Bahrain  2021-01-12  Pfizer/BioNTech, Sinopharm
# 21  Bahrain  2021-01-13  Pfizer/BioNTech, Sinopharm
#
#                                            source_url  total_vaccinations  \
# 0   https://twitter.com/MOH_Bahrain/status/1341855...               38965
# 1   https://twitter.com/MOH_Bahrain/status/1342189...               50071
# 2   https://twitter.com/MOH_Bahrain/status/1342560...               50543
# 3   https://twitter.com/MOH_Bahrain/status/1342912...               51556
# 4   https://twitter.com/MOH_Bahrain/status/1343274...               53614
# 5   https://twitter.com/MOH_Bahrain/status/1343640...               55014
# 6   https://twitter.com/MOH_Bahrain/status/1343999...               56041
# 7   https://twitter.com/MOH_Bahrain/status/1344362...               57317
# 8   https://twitter.com/MOH_Bahrain/status/1344726...               58643
# 9   https://twitter.com/MOH_Bahrain/status/1345086...               59351
# 10  https://twitter.com/MOH_Bahrain/status/1345450...               60097
# 11  https://twitter.com/MOH_Bahrain/status/1345812...               60689
# 12  https://twitter.com/MOH_Bahrain/status/1346173...               61612
# 13  https://twitter.com/MOH_Bahrain/status/1346544...               63893
# 14  https://twitter.com/MOH_Bahrain/status/1346919...               68472
# 15  https://twitter.com/MOH_Bahrain/status/1347269...               72239
# 16  https://twitter.com/MOH_Bahrain/status/1347636...               78291
# 17  https://twitter.com/MOH_Bahrain/status/1347998...               84157
# 18  https://twitter.com/MOH_Bahrain/status/1348359...               89250
# 19  https://twitter.com/MOH_Bahrain/status/1348718...               92598
# 20  https://twitter.com/MOH_Bahrain/status/1349090...               97776
# 21  https://twitter.com/MOH_Bahrain/status/1349446...              101363
#
#     people_vaccinated  people_fully_vaccinated
# 0             38965.0                        0
# 1             50071.0                        0
# 2             50543.0                        0
# 3             51556.0                        0
# 4             53614.0                        0
# 5             55014.0                        0
# 6             56041.0                        0
# 7             57317.0                        0
# 8             58643.0                        0
# 9             59351.0                        0
# 10            60097.0                        0
# 11            60689.0                        0
# 12            61612.0                        0
# 13            63893.0                        0
# 14            68472.0                        0
# 15            72239.0                        0
# 16            78291.0                        0
# 17            84157.0                        0
# 18            89250.0                        0
# 19            92598.0                        0
# 20            97776.0                        0
# 21           101363.0                        0

# %%
country_df.columns
# Out:
# Index(['location', 'date', 'vaccine', 'source_url', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated'],
#       dtype='object')

# %%
country_df.head()
# Out:
#     location        date    vaccine  \
# 0  Argentina  2020-12-29  Sputnik V
# 1  Argentina  2020-12-31  Sputnik V
# 2  Argentina  2021-01-04  Sputnik V
# 3  Argentina  2021-01-08  Sputnik V
# 4  Argentina  2021-01-13  Sputnik V
#
#                                           source_url  total_vaccinations  \
# 0  https://www.argentina.gob.ar/noticias/ministro...                 700
# 1  https://www.argentina.gob.ar/sites/default/fil...               32013
# 2  https://www.argentina.gob.ar/sites/default/fil...               39599
# 3  https://www.argentina.gob.ar/noticias/ya-se-ap...              107542
# 4  https://www.argentina.gob.ar/noticias/continua...              166833
#
#    people_vaccinated  people_fully_vaccinated
# 0              700.0                        0
# 1            32013.0                        0
# 2            39599.0                        0
# 3           107542.0                        0
# 4           166833.0                        0

# %%
country_df.location.nunique()
# Out:
# 53

# %%
vaccinations_df = pd.read_csv(os.path.join(vaccination_path, 'vaccinations.csv'))

# %%
vaccinations_df.shape
# Out:
# (815, 12)

# %%
vaccinations_df.head()
# Out:
#     location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Argentina      ARG  2020-12-29               700.0              700.0
# 1  Argentina      ARG  2020-12-30                 NaN                NaN
# 2  Argentina      ARG  2020-12-31             32013.0            32013.0
# 3  Argentina      ARG  2021-01-01                 NaN                NaN
# 4  Argentina      ARG  2021-01-02                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN             15656.0
# 2                      NaN                     NaN             15656.0
# 3                      NaN                     NaN             11070.0
# 4                      NaN                     NaN              8776.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.00                           0.00
# 1                             NaN                            NaN
# 2                            0.07                           0.07
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                           346.0
# 2                                  NaN                           346.0
# 3                                  NaN                           245.0
# 4                                  NaN                           194.0

# %%
locations_df = pd.read_csv(os.path.join(vaccination_path, 'locations.csv'))

# %%
locations_df.shape
# Out:
# (53, 6)

# %%
selected_features = ["location", "vaccines", "source_name", "source_website"]
country_vaccination_df = vaccinations_df.merge(locations_df[selected_features], on = ["location"])

# %%
locations_df.head()
# Out:
#     location iso_code                    vaccines last_observation_date  \
# 0  Argentina      ARG                   Sputnik V            2021-01-13
# 1    Austria      AUT             Pfizer/BioNTech            2021-01-13
# 2    Bahrain      BHR  Pfizer/BioNTech, Sinopharm            2021-01-13
# 3    Belgium      BEL             Pfizer/BioNTech            2021-01-13
# 4   Bulgaria      BGR             Pfizer/BioNTech            2021-01-13
#
#                                     source_name  \
# 0                       Government of Argentina
# 1                            Ministry of Health
# 2                            Ministry of Health
# 3  Regional governments via covid-vaccinatie.be
# 4                            Ministry of Health
#
#                                       source_website
# 0  https://www.argentina.gob.ar/noticias/continua...
# 1  https://info.gesundheitsministerium.gv.at/data...
# 2  https://twitter.com/MOH_Bahrain/status/1349446...
# 3                     https://covid-vaccinatie.be/en
# 4               https://coronavirus.bg/bg/statistika

# %%
country_vaccination_df.columns
# Out:
# Index(['location', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %%
output_selected_columns = ['country', 'iso_code', 'date', 'total_vaccinations',
'people_vaccinated', 'people_fully_vaccinated',
       'daily_vaccinations_raw', 'daily_vaccinations',
       'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
       'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
       'vaccines', 'source_name', 'source_website']
country_vaccination_df.columns = output_selected_columns

# %%
country_vaccination_df.to_csv("country_vaccinations.csv", index=False)
